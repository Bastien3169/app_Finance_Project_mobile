# %%
# main.py
import os
import scraping_tickers  # Pour récupérer les tickers
import composition_indices  # Pour obtenir les infos des entreprises par indice
import infos_stocks  # Pour concaténer les informations des entreprises et les stocker en CSV
import infos_indices  # Pour récupérer les infos des indices et les stocker en CSV
import hist_indices  # Pour récupérer l'historique des prix des indices
import hist_stocks  # Pour récupérer l'historique des prix des entreprises
import sql_datas # Pour créer la base de donnée sql

def main_db_datas(dossier_csv, csv_bdd, db_path):

    #scraping_tickers.all_tickers_yf()

    # Étape 1: Scraper les tickers de chaque indice et Récupérer les informations des entreprises pour chaque indice
    composition_indices.csv_indices(dossier_csv)

    # Étape 2: Concaténer et sauvegarder les données des entreprises
    infos_stocks.infos_stocks(dossier_csv, csv_bdd) 

    # Étape 3: Récupérer et sauvegarder les informations des indices
    infos_indices.infos_indices(dossier_csv, csv_bdd)

    # Étape 4: Récupérer et sauvegarder l'historique des prix des indices
    hist_indices.recuperer_et_clean_indices(csv_bdd)

    # Étape 5: Récupérer et sauvegarder l'historique des prix des entreprises
    hist_stocks.recuperer_et_clean_stocks(csv_bdd)

    # Étape 6 : Création de la base de donnée
    sql_datas.main_creation_db(csv_bdd, db_path)

    print("[✅]✅] Toutes les étapes ont été exécutées avec succès.")

if __name__ == "__main__":
    main_db_datas("csv", "csv/csv_bdd", "csv/datas.bd")
# Out:
# [✅] Le fichier scraping a bien été enregistré
# Erreur lors de la récupération des données pour RMS.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MC.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour OR.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AIR.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour SU.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour EL.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour SAF.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour TTE.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour SAN.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AI.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CS.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour BNP.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour DG.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour HO.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour SGO.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ACA.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour BN.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ENGI.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour DSY.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour GLE.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ORA.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour STLAP.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour LR.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CAP.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour PUB.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ML.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour STMPA.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour RI.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour VIE.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour KER.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour EN.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour BVI.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour RNO.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour URW.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AC.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ERF.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CA.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour EDEN.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour TEP.PA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MT.AS: Too Many Requests. Rate limited. Try after a while.
# /Users/bastoch/ProjectFinance_alleger/ProjectFinance_Streamlit/src/models/datas_db/composition_indices.py:62: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   total_capitalisation = df['Capitalisation_Boursiere'].fillna(0).sum()
# [✅] Le fichier pour l'indice 'CAC 40' a bien été enregistré sous le nom : csv/composition_france.csv
# Erreur de récupération pour ^DJI: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^NDX: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^FTSE: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^AEX: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^STOXX50E: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^OMXS30: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^BFX: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^FCHI: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^OMXH25: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^OMXC25: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^IBEX: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour FTSEMIB.MI: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^GDAXI: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^N225: Too Many Requests. Rate limited. Try after a while.
# Erreur de récupération pour ^GSPC: Too Many Requests. Rate limited. Try after a while.
# ❌ Aucun historique récupéré, création d'un fichier CSV vide.
# Erreur lors de la récupération des données pour NVDA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MSFT: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AAPL: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AMZN: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour WMT: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour JPM: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour V: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour PG: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour JNJ: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour HD: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour KO: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour UNH: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CSCO: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CRM: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour IBM: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CVX: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MCD: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AXP: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour DIS: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MRK: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour GS: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour VZ: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CAT: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour BA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AMGN: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour HON: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour NKE: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour SHW: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MMM: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour TRV: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour GOOGL: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour GOOG: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour META: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AVGO: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour TSLA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour NFLX: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour COST: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour PLTR: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ASML: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour TMUS: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AZN: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour LIN: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour INTU: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ISRG: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AMD: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour PEP: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour BKNG: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ADBE: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour TXN: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour QCOM: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour PDD: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour SHOP: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ARM: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour GILD: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour APP: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ADP: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MELI: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour PANW: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour AMAT: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CMCSA: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour CRWD: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour VRTX: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour MU: Too Many Requests. Rate limited. Try after a while.
# Erreur lors de la récupération des données pour ADI: Too Many Requests. Rate limited. Try after a while.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 36
#      33     print("[✅]✅] Toutes les étapes ont été exécutées avec succès.")
#      35 if __name__ == "__main__":
# ---> 36     main_db_datas("csv", "csv/csv_bdd", "csv/datas.bd")
#
# Cell In[2], line 28, in main_db_datas(dossier_csv, csv_bdd, db_path)
#      25 hist_indices.recuperer_et_clean_indices(csv_bdd)
#      27 # Étape 5: Récupérer et sauvegarder l'historique des prix des entreprises
# ---> 28 hist_stocks.recuperer_et_clean_stocks(csv_bdd)
#      30 # Étape 6 : Création de la base de donnée
#      31 sql_datas.main_creation_db(csv_bdd, db_path)
#
# File ~/ProjectFinance_alleger/ProjectFinance_Streamlit/src/models/datas_db/hist_stocks.py:15, in recuperer_et_clean_stocks(csv_bdd)
#      13 try:
#      14     ticker = yf.Ticker(i)
# ---> 15     hist = ticker.history(period="max", interval="1wk")
#      17     if hist.empty:
#      18         print(f"⚠️ Historique vide pour {i}.")
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/base.py:82, in TickerBase.history(self, *args, **kwargs)
#      80 @utils.log_indent_decorator
#      81 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 82     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/scrapers/history.py:175, in PriceHistory.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, raise_errors)
#     173         get_fn = self._data.cache_get
#     174 try:
# --> 175     data = get_fn(
#     176         url=url,
#     177         params=params,
#     178         proxy=proxy,
#     179         timeout=timeout
#     180     )
#     181     if "Will be right back" in data.text or data is None:
#     182         raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
#     183                            "Our engineers are working quickly to resolve "
#     184                            "the issue. Thank you for your patience.")
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/data.py:349, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     347 @utils.log_indent_decorator
#     348 def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 349     return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/data.py:406, in YfData._make_request(self, url, request_method, user_agent_headers, body, params, proxy, timeout)
#     404 if strategy == 'basic':
#     405     request_args['cookies'] = {cookie.name: cookie.value}
# --> 406 response = request_method(**request_args)
#     407 utils.get_yf_logger().debug(f'response code={response.status_code}')
#     409 # Raise exception if rate limited
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
