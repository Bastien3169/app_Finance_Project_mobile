# %%
from bs4 import BeautifulSoup
import requests
import time
from datetime import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import html5lib
import os
import glob
    
# Lecture des fichiers
df_crypto_infos = pd.read_csv( "csv/csv_bdd/historique_cryptos.csv")

df_hist = df_crypto_infos.copy()

df_hist["Date"] = pd.to_datetime(df_hist["Date"], errors="coerce").dt.strftime("%d-%m-%Y")


display(df_hist.head())
# Out:
#          Date    Close Ticker_cryptos_Yf Short_Name_Cryptos
# 0  01-09-2014  386.944           BTC-USD            Bitcoin
# 1  01-10-2014  338.321           BTC-USD            Bitcoin
# 2  01-11-2014  378.047           BTC-USD            Bitcoin
# 3  01-12-2014  320.193           BTC-USD            Bitcoin
# 4  01-01-2015  217.464           BTC-USD            Bitcoin
